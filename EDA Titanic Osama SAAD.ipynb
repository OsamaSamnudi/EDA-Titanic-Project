# %% [markdown]
# # Titanic Project
#     * Exploring Data
#     * Bivariate Analysis
#     * Univariate Analysis
#     * Multivariate Analysis

# %% [markdown]
# # Exploring Data

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as plt
import matplotlib.pyplot as plt
sns.set()

# %%
df=pd.read_csv("G:\My Drive\DataSciense\ML_Bootcamp Ahmed Mostafa v91222\Exercises\Data Analysis\Titanic\Train.csv")

# %%
df.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
# Duplicated Valuse :
df.duplicated().sum()
# if there is any duplicated , we can drop them by :
# df.drop_duplicated(inplace=True)
# Out:
# 0

# %%
# Missing Value :
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# Get the (Maen) of every Null :
round((df.isnull().mean())*100,2)
# Out:
# PassengerId     0.00
# Survived        0.00
# Pclass          0.00
# Name            0.00
# Sex             0.00
# Age            19.87
# SibSp           0.00
# Parch           0.00
# Ticket          0.00
# Fare            0.00
# Cabin          77.10
# Embarked        0.22
# dtype: float64

# %%
# Due to 'Embarked'has 22% as missing Data, We can chose between (drop it) or (fill NA) :
# 1) Drop :
    # df.dropna(subset=['Embarked'],inplace=True)
    # Or :
    # df=df.dropna(subset=['Embarked']) as "inplace=True" uses to update the order in same variavle "df"
# 2) FillNA :
    # df['Embarked'].fillna(df['Embarked'].mode()[0], inplace=True)

# %%
# FillNA for Embarked :
df['Embarked'].fillna(df['Embarked'].mode()[0],inplace=True)

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         0
# dtype: int64

# %%
df.isna().sum() # Same as df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         0
# dtype: int64

# %%
df.Age.hist(bins=20);

# %%
# to fill NA with a spacific vaule :
# df.fillna(df.Age.mean(),inplace=True) or df=df.fillna(df.Age.mean())

# %%
# to explore a summary by 2 methods :
df.groupby(['Pclass','Sex'])['Age'].median()
# Out:
# Pclass  Sex
# 1       female    35.0
#         male      40.0
# 2       female    28.0
#         male      30.0
# 3       female    21.5
#         male      25.0
# Name: Age, dtype: float64

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.groupby(['Pclass','Sex'])['Age'].mean()
# Out:
# Pclass  Sex
# 1       female    34.611765
#         male      41.281386
# 2       female    28.722973
#         male      30.740707
# 3       female    21.750000
#         male      26.507589
# Name: Age, dtype: float64

# %%
# To fill NA of Age Based on Bclass & Sex :
df['Age']=df.groupby(['Pclass','Sex'])['Age'].apply(lambda x:x.fillna(x.median()))

# %%
df['Age'].head()
# Out:
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# Name: Age, dtype: float64

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         0
# dtype: int64

# %%
# to drop the unneeded columns :
df.drop(['PassengerId','Name','Ticket','Cabin'],axis=1,inplace=True)

# %%
df.columns=df.columns.str.lower()

# %%
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked'],
#       dtype='object')

# %% [markdown]
# # Univarial Analysis

# %%
# Univarial Analysis
df.survived.value_counts()
# Out:
# 0    549
# 1    342
# Name: survived, dtype: int64

# %%
# get data count avg
df.survived.value_counts(normalize=True)
# Out:
# 0    0.616162
# 1    0.383838
# Name: survived, dtype: float64

# %%
sns.countplot(x='survived',data=df);

# %%
""" To generlize & to be easy to apply the needed for multiple categories,
    we can define function with view & visulise 
    ('survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare','embarked')
"""
def explore_categorical(df,col):
    print(col.upper())
    print(df[col].value_counts(normalize=True))
    sns.countplot(x=col, data=df);
    plt.show()

# %%
for col in ['pclass', 'sibsp', 'parch','embarked','sex']:
    explore_categorical(df,col)
# Out:
# PCLASS
# 3    0.551066
# 1    0.242424
# 2    0.206510
# Name: pclass, dtype: float64
# SIBSP
# 0    0.682379
# 1    0.234568
# 2    0.031425
# 4    0.020202
# 3    0.017957
# 8    0.007856
# 5    0.005612
# Name: sibsp, dtype: float64
# PARCH
# 0    0.760943
# 1    0.132435
# 2    0.089787
# 5    0.005612
# 3    0.005612
# 4    0.004489
# 6    0.001122
# Name: parch, dtype: float64
# EMBARKED
# S    0.725028
# C    0.188552
# Q    0.086420
# Name: embarked, dtype: float64
# SEX
# male      0.647587
# female    0.352413
# Name: sex, dtype: float64

# %%
"""
Define Nomirical Function with histplot diagram
"""
def explore_countinuous (df,col):
    print(col.upper()," :")
    print(df[col].describe())
    sns.histplot(x=col,data=df);
    plt.show()

# %%
df.dtypes
for col in ['age','fare']:
    explore_countinuous(df,col)
# Out:
# AGE  :
# count    891.000000
# mean      29.112424
# std       13.304424
# min        0.420000
# 25%       21.500000
# 50%       26.000000
# 75%       36.000000
# max       80.000000
# Name: age, dtype: float64
# FARE  :
# count    891.000000
# mean      32.204208
# std       49.693429
# min        0.000000
# 25%        7.910400
# 50%       14.454200
# 75%       31.000000
# max      512.329200
# Name: fare, dtype: float64

# %% [markdown]
# # Bivariate Analysis

# %%
df.sample(5)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked
# 182         0       3    male   9.0      4      2  31.3875        S
# 801         1       2  female  31.0      1      1  26.2500        S
# 193         1       2    male   3.0      1      1  26.0000        S
# 169         0       3    male  28.0      0      0  56.4958        S
# 235         0       3  female  21.5      0      0   7.5500        S

# %%
df.groupby('pclass').survived.mean()
# Out:
# pclass
# 1    0.629630
# 2    0.472826
# 3    0.242363
# Name: survived, dtype: float64

# %%
sns.barplot(x='pclass', y='survived',data=df);

# %%
sns.barplot(x='pclass',y='survived',data=df,ci=None);
plt.axhline(df.survived.mean(),color='black',linestyle='-');
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_12828\4045509051.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='pclass',y='survived',data=df,ci=None);

# %%
df.sample(5)
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked
# 603         0       3    male  44.0      0      0    8.0500        S
# 229         0       3  female  21.5      3      1   25.4667        S
# 724         1       1    male  27.0      1      0   53.1000        S
# 700         1       1  female  18.0      1      0  227.5250        C
# 366         1       1  female  60.0      1      0   75.2500        C

# %%
# define a function to see all categorical columns vs survived with general survived rate
def survived_rate(df,col):
    print(df.groupby(col).survived.mean());
    sns.barplot(x=col,y='survived',data=df,ci=None);
    plt.axhline(df.survived.mean(),color='black',linestyle='--')
    plt.axhline(df.survived.max(),color='black',linestyle='-.')
    plt.show()

# %%
for col in ['pclass','sibsp','sex','parch','embarked','sex']:
    survived_rate(df,col)
# Out:
# pclass
# 1    0.624413
# 2    0.472826
# 3    0.242363
# Name: survived, dtype: float64
# C:\Users\HP\AppData\Local\Temp\ipykernel_12828\1658817680.py:4: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x=col,y='survived',data=df,ci=None);
# sibsp
# 0    0.342149
# 1    0.535885
# 2    0.464286
# 3    0.250000
# 4    0.166667
# 5    0.000000
# 8    0.000000
# Name: survived, dtype: float64
# C:\Users\HP\AppData\Local\Temp\ipykernel_12828\1658817680.py:4: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x=col,y='survived',data=df,ci=None);
# sex
# female    0.741214
# male      0.186087
# Name: survived, dtype: float64
# C:\Users\HP\AppData\Local\Temp\ipykernel_12828\1658817680.py:4: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x=col,y='survived',data=df,ci=None);
# parch
# 0    0.341716
# 1    0.547009
# 2    0.500000
# 3    0.600000
# 4    0.000000
# 5    0.200000
# 6    0.000000
# Name: survived, dtype: float64
# C:\Users\HP\AppData\Local\Temp\ipykernel_12828\1658817680.py:4: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x=col,y='survived',data=df,ci=None);
# embarked
# C    0.545455
# Q    0.389610
# S    0.339009
# Name: survived, dtype: float64
# C:\Users\HP\AppData\Local\Temp\ipykernel_12828\1658817680.py:4: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x=col,y='survived',data=df,ci=None);
# sex
# female    0.741214
# male      0.186087
# Name: survived, dtype: float64
# C:\Users\HP\AppData\Local\Temp\ipykernel_12828\1658817680.py:4: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x=col,y='survived',data=df,ci=None);

# %%
sns.histplot(x='age',data=df,hue='survived');

# %%
sns.histplot(x='fare',data=df,hue='survived',multiple='stack');

# %%
sns.histplot(x='fare',data=df,hue='survived');

# %%
# subplot for age :
# Step 1 : Setup the subplot (fig & ax) grafs using matplatlip (plt.Subplot)
# Step 2 : Setup 2 variables for both "Survived(=1) & Died (=0)" Cases :
# Step 3 : Drow the dual Grafs by histpolt :
# Step 4 : Define Titles :
# Step 5 : Show grafs 
fig,ax=plt.subplots(1,2,figsize=(10,3)) # Step 1 subplot Setup

df_survived=df[df.survived==1]         # Step 2 variables
df_died=df[df.survived==0]

sns.histplot(x='age',data=df_survived,ax=ax[0],kde=True,color='green') #Setp 3 Drow the grafs
sns.histplot(x='age',data=df_died,ax=ax[1],kde=True,color='red')

ax[0].set_title('Survived') # Step 4 Defile Titles
ax[1].set_title('Died')

plt.show() # Show grafs

# %%
# subplot for far :
fig,ax=plt.subplots(1,2,figsize=(10,3))
sns.histplot(x='fare',data=df_survived,ax=ax[0],kde=True,color='darkgreen')
sns.histplot(x='fare',data=df_died,ax=ax[1],kde=True,color='red')
ax[0].set_title('Survived')
ax[1].set_title('Died')
plt.show()

# %%
df.groupby('sex')[['age','fare']].mean()
# Out:
#               age       fare
# sex
# female  27.261146  44.479818
# male    30.119879  25.523893

# %%
df.describe()[['age','fare']]
# Out:
#               age        fare
# count  891.000000  891.000000
# mean    29.112424   32.204208
# std     13.304424   49.693429
# min      0.420000    0.000000
# 25%     21.500000    7.910400
# 50%     26.000000   14.454200
# 75%     36.000000   31.000000
# max     80.000000  512.329200

# %%
sns.boxplot(x='age',data=df);

# %%
sns.boxplot(x='fare',data=df)
# Out:
# <AxesSubplot: xlabel='fare'>

# %% [markdown]
# # Outliers Detection : (remove outlires)
#     Q1 25%
#     Q3 75%
#     IQR Q3 - Q1

# %%
# Remove Quantile Values :
def remove_outlires(df,col):
    q1=df[col].quantile(0.25)
    q3=df[col].quantile(0.75)
    iqr=q3-q1
    lower_bound=q1-(1.5*iqr)
    upper_bound=q3-(1.5*iqr)
    return df[(df[col] > lower_bound) & (df[col] < upper_bound)]

# df=remove_outliers(df,'fare')

# %%
df=df[df.fare < 300]

# %%
sns.boxplot(x='fare',data=df);

# %%
df.fare.describe()
# Out:
# count    888.000000
# mean      30.582164
# std       41.176366
# min        0.000000
# 25%        7.895800
# 50%       14.454200
# 75%       30.771850
# max      263.000000
# Name: fare, dtype: float64

# %% [markdown]
# # Split into Groups
# * Cut

# %%
# Spliting Age in Groups (Child , Young , adult, ''Senior)
df['age_group']=pd.cut(df.age,bins=[0,22,27,37,82],labels=['child','young','afult','seniro'])
df['fare_group']=pd.cut(df.fare,bins=[-0.99,8,15,35,265],labels=['low','mediam','high','very high'])

# %%
for col in ['age_group','fare_group']:
    survived_rate(df,col)
# Out:
# age_group
# child     0.450549
# young     0.260000
# afult     0.427184
# seniro    0.363636
# Name: survived, dtype: float64
# C:\Users\HP\AppData\Local\Temp\ipykernel_12828\3510424032.py:4: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x=col,y='survived',data=df,ci=None);
# fare_group
# low          0.215768
# mediam       0.285714
# high         0.446809
# very high    0.615385
# Name: survived, dtype: float64
# C:\Users\HP\AppData\Local\Temp\ipykernel_12828\3510424032.py:4: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x=col,y='survived',data=df,ci=None);

# %%
# Create New Feature: "family_size" to combine "parch" and " sibsp" and explore it with Survival Rate
df['family_size']=df.parch+df.sibsp
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'age_group', 'fare_group', 'family_size'],
#       dtype='object')

# %%
df.embarked.describe()
df.groupby('embarked')['sex'].describe()
# Out:
#          count unique   top freq
# embarked
# C          165      2  male   93
# Q           77      2  male   41
# S          646      2  male  441

# %%
# How many passengers were alone? What is their Survival Rate ?
for col in ['family_size']:
    survived_rate(df,col)
# Out:
# family_size
# 0     0.300935
# 1     0.550000
# 2     0.578431
# 3     0.724138
# 4     0.200000
# 5     0.136364
# 6     0.333333
# 7     0.000000
# 10    0.000000
# Name: survived, dtype: float64
# C:\Users\HP\AppData\Local\Temp\ipykernel_18548\3510424032.py:4: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x=col,y='survived',data=df,ci=None);

# %%
# How many passengers were alone? What is their Survival Rate ?
print("How many passengers were alone?\n",df['family_size'].value_counts()[0])
# Out:
# How many passengers were alone?
#  535

# %%
# What is their Survival Rate ?
print("\nWhat is their Survival Rate ?")
df['family_size'].value_counts()[0]/df['family_size'].value_counts().sum()
# Out:
# What is their Survival Rate ?
# 0.6024774774774775

# %%
# What are top 3 categories from "family_size" have highest survival Rate ?
df.groupby('family_size').survived.count().head(3) # Way 1
Top=df.groupby('family_size').survived.count().nlargest(3) # Way 2
fig,ax=plt.subplots()
ax.pie(Top,labels=Top);

# %%
# Try differnet age groups
df['newage_group']=pd.cut(df.age,bins=[0,10,15,22,37,85],labels=['baby','child','young','adult','senior'])
df.groupby('newage_group')['survived'].count()
for col in ['newage_group','sex']:
    survived_rate(df,col)
# Out:
# newage_group
# baby      0.593750
# child     0.578947
# young     0.331081
# adult     0.404110
# senior    0.377660
# Name: survived, dtype: float64
# C:\Users\HP\AppData\Local\Temp\ipykernel_18548\3510424032.py:4: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x=col,y='survived',data=df,ci=None);
# sex
# female    0.741214
# male      0.186087
# Name: survived, dtype: float64
# C:\Users\HP\AppData\Local\Temp\ipykernel_18548\3510424032.py:4: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x=col,y='survived',data=df,ci=None);

# %% [markdown]
# # Multivarial

# %%
# pariplot
sns.pairplot(df,hue='survived')

# %%
df.corr()
df.corr().survived
# Out:
# survived       1.000000
# pclass        -0.334068
# age           -0.079472
# sibsp         -0.033395
# parch          0.082157
# fare           0.261742
# family_size    0.018211
# Name: survived, dtype: float64

# %%
plt.figure(figsize=(10,8))
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot: >

# %%
sns.barplot(x='pclass',y='survived',data=df,hue='sex',ci=None)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_18548\2502158668.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='pclass',y='survived',data=df,hue='sex',ci=None)
# <AxesSubplot: xlabel='pclass', ylabel='survived'>

# %%
sns.barplot(x='embarked',y='survived',data=df,hue='sex',ci=None)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_18548\2960221231.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='embarked',y='survived',data=df,hue='sex',ci=None)
# <AxesSubplot: xlabel='embarked', ylabel='survived'>

# %%
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'age_group', 'fare_group', 'family_size', 'newage_group'],
#       dtype='object')

# %% [markdown]
# # Conclusion

# %%
df.head(1)
# Out:
#    survived  pclass   sex   age  sibsp  parch  fare embarked age_group  \
# 0         0       3  male  22.0      1      0  7.25        S     child
#
#   fare_group  family_size newage_group
# 0        low            1        young

# %%
# Creta 7 subplots for all :
# Setp 1 : setup 'subplots' setting for (fig & ax)
# Setp 2 : create for loop with list the columns name with two variables i (for ax) & Col (for Columns)
    # drow 'barplots' with x (for col) , y for (survived)
# Step 3 : show charts

fig,ax=plt.subplots(2,4,figsize=(15,8))
for i , col in enumerate(['pclass', 'sex', 'sibsp', 'parch', 'embarked', 'age_group', 'fare_group', 'family_size']):
    sns.barplot(x=col,y='survived',data=df,ci=None,ax=ax[i//4,i%4])
    ax[i//4,i%4].axhline(df.survived.mean(),color="black",linestyle="--")
plt.tight_layout()
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_18548\215662777.py:9: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x=col,y='survived',data=df,ci=None,ax=ax[i//4,i%4])
# C:\Users\HP\AppData\Local\Temp\ipykernel_18548\215662777.py:9: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x=col,y='survived',data=df,ci=None,ax=ax[i//4,i%4])
# C:\Users\HP\AppData\Local\Temp\ipykernel_18548\215662777.py:9: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x=col,y='survived',data=df,ci=None,ax=ax[i//4,i%4])
# C:\Users\HP\AppData\Local\Temp\ipykernel_18548\215662777.py:9: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x=col,y='survived',data=df,ci=None,ax=ax[i//4,i%4])
# C:\Users\HP\AppData\Local\Temp\ipykernel_18548\215662777.py:9: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x=col,y='survived',data=df,ci=None,ax=ax[i//4,i%4])
# C:\Users\HP\AppData\Local\Temp\ipykernel_18548\215662777.py:9: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x=col,y='survived',data=df,ci=None,ax=ax[i//4,i%4])
# C:\Users\HP\AppData\Local\Temp\ipykernel_18548\215662777.py:9: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x=col,y='survived',data=df,ci=None,ax=ax[i//4,i%4])
# C:\Users\HP\AppData\Local\Temp\ipykernel_18548\215662777.py:9: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x=col,y='survived',data=df,ci=None,ax=ax[i//4,i%4])

# %%
female_df=df[df.sex=='female']
male_df=df[df.sex=='male']

# %%
female_df.survived.value_counts(normalize=True)
# Out:
# 1    0.741214
# 0    0.258786
# Name: survived, dtype: float64

# %%
male_df.survived.value_counts(normalize=True)
# Out:
# 0    0.813913
# 1    0.186087
# Name: survived, dtype: float64

# %%
female_df.groupby('pclass').survived.mean(0)
# Out:
# pclass
# 1    0.967742
# 2    0.921053
# 3    0.500000
# Name: survived, dtype: float64

# %%
sns.barplot(x='pclass',y='survived',data=female_df,ci=None)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_18548\886404058.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='pclass',y='survived',data=female_df,ci=None)
# <AxesSubplot: xlabel='pclass', ylabel='survived'>

# %%
sns.barplot(x='pclass',y='survived',data=male_df,ci=None);
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_18548\982231930.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='pclass',y='survived',data=male_df,ci=None);

# %%
# mearg two data frame :
sex_class=pd.merge(female_df.groupby('pclass').survived.mean(),male_df.groupby('pclass').survived.mean(),on='pclass')
sex_class
# Out:
#         survived_x  survived_y
# pclass
# 1         0.967742    0.358333
# 2         0.921053    0.157407
# 3         0.500000    0.135447

# %%
df.groupby('pclass').survived.mean().nsmallest()
# Out:
# pclass
# 3    0.242363
# 2    0.472826
# 1    0.624413
# Name: survived, dtype: float64
